# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3edbe1ce-00f7-4c65-bebb-245e3a62db1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3edbe1ce-00f7-4c65-bebb-245e3a62db1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kc_house_data.csv to kc_house_data.csv

# %%
import numpy as np
import pandas as pd
import statistics  
df=pd.read_csv('/content/kc_house_data.csv',sep=',')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
corr = df.corr()
corr.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_a6247_row0_col0, #T_a6247_row1_col1, #T_a6247_row2_col2, #T_a6247_row3_col3, #T_a6247_row4_col4, #T_a6247_row5_col5, #T_a6247_row6_col6, #T_a6247_row7_col7, #T_a6247_row8_col8, #T_a6247_row9_col9, #T_a6247_row10_col10, #T_a6247_row11_col11, #T_a6247_row12_col12, #T_a6247_row13_col13, #T_a6247_row14_col14, #T_a6247_row15_col15, #T_a6247_row16_col16, #T_a6247_row17_col17, #T_a6247_row18_col18, #T_a6247_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a6247_row0_col1, #T_a6247_row2_col7, #T_a6247_row9_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_a6247_row0_col2, #T_a6247_row5_col1, #T_a6247_row7_col5, #T_a6247_row8_col16, #T_a6247_row9_col14, #T_a6247_row14_col19 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_a6247_row0_col3, #T_a6247_row3_col9, #T_a6247_row4_col16, #T_a6247_row6_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# ...

# %%
import seaborn as sns
sns.boxplot(df['price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#from the heatmap the most important featers according to the correlation are:
#sqft_living
#sqft_above 
#sqft_basement	
#sqft_living15
#bathrooms
#bedrooms yr_built lat sqft_living15 won t be taken to speed up the procees
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40)

model=LinearRegression()   
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417
# 0.49278169994876087

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("sqft_living")
plt.xlabel("price")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df[["sqft_living","sqft_above","sqft_basement","sqft_living15","bathrooms"]]

y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40)

model=LinearRegression()   
model.fit(x_train,y_train) 
predicted=model.predict(x_test) 


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 61915032932.83281
# R squared 0.5075067684075077
# 0.5011846265757582

# %%
from sklearn.preprocessing import PolynomialFeatures 
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) 
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  58237063962.54638
# R squared:  0.5367625846135381

# %%
x=df[["sqft_living","sqft_above","sqft_basement","sqft_living15","bathrooms"]]
y=df["price"].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) 
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57204489754.547905
# R squared:  0.544976031081505
